# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/06/how-to-load-kaggle-datasets-directly-into-google-colab/
#
# Drag the kaggle.json file to directory, outside sample_data. then fire following commands.

# %%
 ! pip install -q kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# paste the API command here. Prefixed by '!'
# !kaggle datasets download -d shrutimechlearn/churn-modelling

# you will see the files in the root location.
# Out:
# ...
#   0% 0.00/262k [00:00<?, ?B/s]
# 100% 262k/262k [00:00<00:00, 76.3MB/s]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !unzip churn-modelling.zip
# Out:
# Archive:  churn-modelling.zip
#   inflating: Churn_Modelling.csv

# %%
import pandas as pd
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...
